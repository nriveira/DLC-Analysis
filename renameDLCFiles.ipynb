# %%
## Code to check if the renaming process works properly.
import os

directory = r"C:\Users\nrive\Research\AnkG\DLC_Vids\iteration1\Mouse-3"

for (dirpath, _ , filenames) in os.walk(directory):
    for filename in filenames:
        if filename.endswith('.avi'): 
            filePath = dirpath + '\\' + filename
            
            splitDir = dirpath.split('\\')
            parentDir = ''
            for n in splitDir[:7]:
                parentDir += n + '\\'
            
            dirName = ''.join(splitDir[7:]) 
            destPath = parentDir + dirName + filename
            
            print(filePath + ':\n' + destPath + '\n')
# Out:
# C:\Users\nrive\Research\AnkG\DLC_Vids\iteration1\Mouse-3\Day1\Begin1\DV10.avi:
# C:\Users\nrive\Research\AnkG\DLC_Vids\iteration1\Mouse-3Day1Begin1DV10.avi
#
# C:\Users\nrive\Research\AnkG\DLC_Vids\iteration1\Mouse-3\Day1\Begin1\DV100.avi:
# C:\Users\nrive\Research\AnkG\DLC_Vids\iteration1\Mouse-3Day1Begin1DV100.avi
#
# C:\Users\nrive\Research\AnkG\DLC_Vids\iteration1\Mouse-3\Day1\Begin1\DV101.avi:
# C:\Users\nrive\Research\AnkG\DLC_Vids\iteration1\Mouse-3Day1Begin1DV101.avi
#
# C:\Users\nrive\Research\AnkG\DLC_Vids\iteration1\Mouse-3\Day1\Begin1\DV102.avi:
# C:\Users\nrive\Research\AnkG\DLC_Vids\iteration1\Mouse-3Day1Begin1DV102.avi
#
# C:\Users\nrive\Research\AnkG\DLC_Vids\iteration1\Mouse-3\Day1\Begin1\DV103.avi:
# C:\Users\nrive\Research\AnkG\DLC_Vids\iteration1\Mouse-3Day1Begin1DV103.avi
#
# C:\Users\nrive\Research\AnkG\DLC_Vids\iteration1\Mouse-3\Day1\Begin1\DV104.avi:
# C:\Users\nrive\Research\AnkG\DLC_Vids\iteration1\Mouse-3Day1Begin1DV104.avi
#
# ...

# %%
## Code to move all files to the same directory.
for (dirpath, _ , filenames) in os.walk(directory):
    for filename in filenames:
        if filename.endswith('.csv'): 
            filePath = dirpath + '\\' + filename
            
            splitDir = dirpath.split('\\')
            parentDir = ''
            for n in splitDir[:7]:
                parentDir += n + '\\'
            
            dirName = ''.join(splitDir[6:]) 
            destPath = parentDir + dirName + filename
            
            os.rename(filePath, destPath)

# %%
## Code to check if the renaming process works properly.
import os

directory = r"C:\Users\nrive\Research\AnkG\DLC_Vids\iteration1\Mouse-23"

for (dirpath, _ , filenames) in os.walk(directory):
    for filename in filenames:
        if filename.endswith('.avi'): 
            filePath = dirpath + '\\' + filename
            
            splitDir = dirpath.split('\\')
            parentDir = ''
            for n in splitDir[:7]:
                parentDir += n + '\\'
            
            dirName = ''.join(splitDir[7:]) 
            destPath = directory + '\\' + dirName + filename
            
            os.rename(filePath, destPath)
            print(filePath + ':\n' + destPath + '\n')
# Out:
# C:\Users\nrive\Research\AnkG\DLC_Vids\iteration1\Mouse-23\Day1\Begin1\DV0.avi:
# C:\Users\nrive\Research\AnkG\DLC_Vids\iteration1\Mouse-23\Mouse-23Day1Begin1DV0.avi
#
# C:\Users\nrive\Research\AnkG\DLC_Vids\iteration1\Mouse-23\Day1\Begin1\DV1.avi:
# C:\Users\nrive\Research\AnkG\DLC_Vids\iteration1\Mouse-23\Mouse-23Day1Begin1DV1.avi
#
# C:\Users\nrive\Research\AnkG\DLC_Vids\iteration1\Mouse-23\Day1\Begin1\DV10.avi:
# C:\Users\nrive\Research\AnkG\DLC_Vids\iteration1\Mouse-23\Mouse-23Day1Begin1DV10.avi
#
# C:\Users\nrive\Research\AnkG\DLC_Vids\iteration1\Mouse-23\Day1\Begin1\DV100.avi:
# C:\Users\nrive\Research\AnkG\DLC_Vids\iteration1\Mouse-23\Mouse-23Day1Begin1DV100.avi
#
# C:\Users\nrive\Research\AnkG\DLC_Vids\iteration1\Mouse-23\Day1\Begin1\DV101.avi:
# C:\Users\nrive\Research\AnkG\DLC_Vids\iteration1\Mouse-23\Mouse-23Day1Begin1DV101.avi
#
# C:\Users\nrive\Research\AnkG\DLC_Vids\iteration1\Mouse-23\Day1\Begin1\DV102.avi:
# ...
